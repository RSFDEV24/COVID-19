# %% [markdown]
# <a href="https://colab.research.google.com/github/RSFDEV24/COVID-19/blob/master/Python%20Fundamentals_Excercise1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = 100
